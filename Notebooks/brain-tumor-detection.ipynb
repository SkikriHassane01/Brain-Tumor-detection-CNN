# %% [markdown]
# <div style ="font-family:Trebuchet MS; background-color : #f8f0fa; border-left: 5px solid #1b4332; padding: 12px; border-radius: 50px 50px;">
#     <h2 style="color: #1b4332; font-size: 48px; text-align: center;">
#         <b> Brain Tumor 🧠 detection</b>
#         <hr style="border-top: 2px solid #264653;">
#         <br>
#         <img style="width: 60%; height: auto; padding: 20px  auto; margin: 20px auto; display: block ; display: block; border-radius: 50px 50px;" src="https://onco.com/about-cancer/wp-content/uploads/2019/02/Brain_Tumor-1-1024x683.jpg">
#     </h2>
#     <hr style="border-top: 2px solid #264653;">
#     <h3 style="font-size: 14px; color: #264653; text-align: left; "><strong> I hope this is very helpful. let's started .😊🌟</strong></h3>
# </div>

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Outline🌟🔻
# </h1>

# %% [markdown]
# <div style="background-color: #fcf8e8; /* Notepad yellow */
#            font-family: 'Times New Roman', serif; /* Classic font for note-taking */
#            color: #000;
#            font-size: 16px; /* Standard text size */
#            line-height: 1.5; /* Spacing between lines of text */
#            text-align: left;
#            border-radius: 5px;
#            padding: 20px;
#            margin: 20px;
#            width: 90%;
#            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2); /* Realistic shadow */
#            background-image: linear-gradient(rgba(0, 0, 0, 0.1) 1px, transparent 1px),
#                              linear-gradient(to right, rgba(0, 0, 0, 0.1) 1px, transparent 1px);
#            background-size: 100% 30px, 30px 100%; /* Size of the lines */
#            border: 1px solid #ddd; /* Border for paper edge */
#            ">
#     <ul>
#         <li>Overview about the project 📋</li>
#         <li>Import libraries 📂</li>
#         <li>Data Preprocessing</li>
#         <li>Modeling 🧠</li>
#         <li>Testing & Save the model 🎯</li>
#     </ul>
# </div>

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Overview about the project 🌟🔻</h1>

# %% [markdown]
# <div style="background-color: #fcf8e8; /* Notepad yellow */
#            font-family: 'Times New Roman', serif; /* Classic font for note-taking */
#            color: #000;
#            font-size: 16px; /* Standard text size */
#            line-height: 1.5; /* Spacing between lines of text */
#            text-align: left;
#            border-radius: 5px;
#            padding: 20px;
#            margin: 20px;
#            width: 90%;
#            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2); /* Realistic shadow */
#            background-image: linear-gradient(rgba(0, 0, 0, 0.1) 1px, transparent 1px),
#                              linear-gradient(to right, rgba(0, 0, 0, 0.1) 1px, transparent 1px);
#            background-size: 100% 30px, 30px 100%; /* Size of the lines */
#            border: 1px solid #ddd; /* Border for paper edge */
#            ">
#     <hr>
#     <p>
# <code>What is brain tumor</code>
# <p>A brain tumor is a mass of abnormal cells that grows in the brain. It can be either cancerous or noncancerous. The tumor may cause an increase in pressure inside the skull, resulting in potential brain damage and life-threatening consequences.</p>
# <code> importance of deep learning</code>
# <p>The use of deep learning in healthcare is proving to be very effective in improving the diagnosis of health conditions. The World Health Organization states that proper diagnosis of brain tumors involves detecting tumors, identifying their location, and classifying them based on factors like malignancy, grade, and type. An experimental approach using Magnetic Resonance Imaging (MRI) has been developed to achieve this. This method involves using a single model to classify brain MRI images for different tasks, rather than using separate models for each task. A Convolutional Neural Network (CNN) based multi-task classification approach is used to classify and detect tumors. Additionally, a CNN-based model is used to identify the location of brain tumors through segmentation.</p>
# <code>Dataset</code>
# <p>This dataset is a combination of the following three datasets :
# figshare
# SARTAJ dataset
# Br35H
#
# This dataset contains 7023 images of human brain MRI images which are classified into 4 classes: glioma - meningioma - no tumor and pituitary.
#
# Glioma: A type of tumor that arises from the glial cells in the brain. Gliomas can vary in severity and can be either benign or malignant.
#
# Meningioma: A usually benign tumor that develops in the meninges, which are the protective layers of tissue surrounding the brain and spinal cord.
#
# No tumor: This category refers to brain MRI images that do not show any evidence of a tumor or abnormal growth in the brain.
#
# Pituitary: This refers to conditions related to the pituitary gland, which is a small gland at the base of the brain that regulates various bodily functions through the production and release of hormones. Tumors can also develop in the pituitary gland.
#     </p>
# </div>

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Import libraries 🌟🔻</h1>

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image as Img
import cv2

import os

import pickle

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# deep learning
import tensorflow as tf
import keras
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dropout, Flatten, Dense, Input, MaxPooling2D

from tensorflow.keras.optimizers import Adam

# Image augmentation importrs
from tensorflow.keras.utils import load_img
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import RandomRotation, RandomContrast, RandomZoom, RandomFlip, RandomTranslation

# Training Model callbacks
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

import random

# %matplotlib inline
plt.style.use('ggplot')
# Out:
# 2024-07-23 11:39:55.029527: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-23 11:39:55.029668: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-23 11:39:55.154491: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# general parameters 

plt.rcParams["figure.figsize"] = (18, 9)
plt.rcParams.update({'font.size': 15})

# %%
# Check if GPU is available
print(f'Tensorflow Version: {tf.__version__}')
print("GPU Available:", tf.config.list_physical_devices('GPU')[0])
# Out:
# Tensorflow Version: 2.15.0
# GPU Available: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Data Preprocessing 🌟🔻</h1>

# %%
path_train = "/kaggle/input/brain-tumor-mri-dataset/Training"
path_test = "/kaggle/input/brain-tumor-mri-dataset/Testing"

number_of_images_train = {}
number_of_images_test = {}

for dir in os.listdir(path_train):
    number_of_images_train[dir] = len(os.listdir(os.path.join(path_train, dir)))
    
for dir in os.listdir(path_test):
    number_of_images_test[dir] = len(os.listdir(os.path.join(path_test, dir)))
    
print("training examples: ",number_of_images_train.items())
print("testing examples: ",number_of_images_test.items())
# Out:
# training examples:  dict_items([('pituitary', 1457), ('notumor', 1595), ('meningioma', 1339), ('glioma', 1321)])
# testing examples:  dict_items([('pituitary', 300), ('notumor', 405), ('meningioma', 306), ('glioma', 300)])

# %%
# first let's group our data set into X_data and Y_data  

X_data = []
Y_data = []

image_size = 168
labels = ['glioma','meningioma','notumor','pituitary']

for i in labels:
    # training
    folderPath = os.path.join('/kaggle/input/brain-tumor-mri-dataset/Training',i)
    for j in os.listdir(folderPath):
        img = cv2.imread(os.path.join(folderPath,j))
        # scaling 
        img = cv2.resize(img,(image_size,image_size))
        X_data.append(img)
        Y_data.append(i)

for i in labels:
    # testing 
    folderPath = os.path.join('/kaggle/input/brain-tumor-mri-dataset/Testing',i)
    for j in os.listdir(folderPath):
        img = cv2.imread(os.path.join(folderPath,j))
        # scaling 
        img = cv2.resize(img,(image_size,image_size))
        X_data.append(img)
        Y_data.append(i)

# %%
# let's view our dataset

paths = [
    '/kaggle/input/brain-tumor-mri-dataset/Training/glioma',
    '/kaggle/input/brain-tumor-mri-dataset/Training/meningioma',
    '/kaggle/input/brain-tumor-mri-dataset/Training/notumor',
    '/kaggle/input/brain-tumor-mri-dataset/Training/pituitary'
]

# Collect all image file paths
all_image_files = []
for path in paths:
    image_files = os.listdir(path)
    full_paths = [os.path.join(path, img_file) for img_file in image_files]
    all_image_files.extend(full_paths)

# Select 12 random images
random_images = random.sample(all_image_files, 12)

# Plot the images
plt.figure(figsize=(14, 10))
plt.suptitle('Random images from our dataset', fontsize=16, y=1.02)

for i, image_file in enumerate(random_images):
    Image = image.load_img(image_file)
    plt.subplot(3, 4, i + 1)
    plt.imshow(Image)

    base_name = os.path.basename(image_file)
    
    if base_name.startswith('Tr-gl_') or base_name.startswith('Tr-glTr_'):
        plt.title('glioma')
    elif base_name.startswith('Tr-me_') or base_name.startswith('Tr-meTr_'):
        plt.title('meningioma')
    elif base_name.startswith('Tr-no_') or base_name.startswith('Tr-noTr_'):
        plt.title('notumor')
    elif base_name.startswith('Tr-pi_') or base_name.startswith('Tr-piTr_'):
        plt.title('pituitary')

    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# count the numer of each disease
names, counts = np.unique(Y_data, return_counts=True)

print(names)
print(counts)
print(sum(counts))

fig = plt.figure(figsize=(12,6))
bars = plt.bar(names, counts, color='skyblue')
plt.title('count the number if each disease')
plt.xlabel('Tumors disease')
plt.ylabel('Counts')

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 20, yval, ha='center', va='bottom', fontsize=9)
plt.tight_layout()
plt.show()
# Out:
# ['glioma' 'meningioma' 'notumor' 'pituitary']
# [1621 1645 2000 1757]
# 7023

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Data augmentation 🌟🔻</h1>

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

batch_size = 32


train_ds = image_dataset_from_directory(
    path_train,
    validation_split=0.2,  # Use 20% of data for validation
    subset="training",
    seed=123,
    image_size=(168, 168),
    batch_size=batch_size
)

test_ds = image_dataset_from_directory(
    path_test,
    validation_split=0.2,  
    subset="validation",
    seed=123,
    image_size=(168, 168),
    batch_size=batch_size
)



data_augmentation = Sequential([
    RandomFlip("horizontal"),
    RandomRotation(0.02, fill_mode='constant'),
    RandomContrast(0.1),
    RandomZoom(height_factor=0.01, width_factor=0.05),
    RandomTranslation(height_factor=0.0015, width_factor=0.0015, fill_mode='constant'),
])

# Training augmentation and normalization
def preprocess_train(image, label):
    # Apply data augmentation and Normalize
    image = data_augmentation(image) / 255.0
    return image, label

# For test dataset only applying normalization
def preprocess_test(image, label):
    return image / 255.0, label

# Apply transformation to training and testing datasets
train_ds_preprocessed = train_ds.map(preprocess_train, num_parallel_calls=tf.data.AUTOTUNE)
test_ds_preprocessed = test_ds.map(preprocess_test, num_parallel_calls=tf.data.AUTOTUNE)
# Out:
# Found 5712 files belonging to 4 classes.
# Using 4570 files for training.
# Found 1311 files belonging to 4 classes.
# Using 262 files for validation.

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻  Building CNN Model 🚊🔻</h1>

# %% [markdown]
# ### 1. Understanding Convolutional Layer (Conv2D)
#
# - **Filters**: Number of output filters in the convolution. Captures a variety of features from the input. Determines the depth of the output feature map.
# - **Kernel Size**: Size of the convolution window. Small kernels capture local features, while larger kernels capture more global features. Defines the area of input considered during each convolution.
# - **Strides**: Step size at which the convolution window moves across the input. Larger strides can reduce spatial dimensions, capturing broader features. Affects the dimensionality of the output feature map.
# - **Padding**: Adds zeros to the input's edges to maintain size. Ensures edge features are processed effectively. Influences the size of the output feature map.
# - **Activation**: Non-linear function applied to introduce non-linearity. Allows the network to learn complex patterns. Examples include ReLU (Rectified Linear Unit).
#
# ### 2. Understanding Pooling Layer (MaxPooling2D, AvgPooling2D)
#
# - **Pool Size**: The size of the pooling window. Downsamples the input representation. Makes the features more robust to variations and translations.
# - **Strides and Padding**: Similar to convolutional layers, they influence the output size. Controls how pooling is applied across the input. Larger strides in pooling mean fewer pooled regions, making the output smaller.
#
#
# ### 3. Understanding Dropout
#
# - **Dropout**: A regularization technique that randomly sets a fraction of input units to zero during training. Helps prevent overfitting by ensuring that the model does not rely too heavily on any single neuron. Typically applied to fully connected layers.
#
# ### 4. Understanding Flatten
#
# - **Flatten**: Converts the 2D or 3D feature maps into a 1D vector. Prepares the data for input into fully connected (dense) layers. Maintains all the information from the feature maps.
#
# ### 5. Understanding Dense (Fully Connected) Layers
#
# - **Dense Layer**: A layer where each neuron is connected to every neuron in the previous layer. Used for making final predictions or decisions based on the features extracted by previous layers. Transforms the input into output through learned weights.

# %%
# Building model
model = Sequential([
    # Input tensor shape
    Input(shape=(168, 168, 3)), 
    
    # Convolutional layer 1
    Conv2D(64, (5, 5), activation="relu"),
    MaxPooling2D(pool_size=(3, 3)),

    # Convolutional layer 2
    Conv2D(64, (5, 5), activation="relu"),
    MaxPooling2D(pool_size=(3, 3)),

    # Convolutional layer 3
    Conv2D(128, (4, 4), activation="relu"),
    MaxPooling2D(pool_size=(2, 2)),

    # Convolutional layer 4
    Conv2D(128, (4, 4), activation="relu"),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),

    # Dense layers
    Dense(512, activation="relu"),
    Dense(4, activation="softmax")
])

# Model summary
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 164, 164, 64)   │         4,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 50, 50, 64)     │       102,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 13, 13, 128)    │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 3, 3, 128)      │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 1, 1, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         2,052 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 568,900 (2.17 MB)
#  Trainable params: 568,900 (2.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = Adam(learning_rate=0.001, beta_1=0.85, beta_2=0.9925)
model.compile(loss='sparse_categorical_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);">
#     🔻🌟 Training  🌟🔻</h1>
#
# `ReduceLROnMultipleAccuracies Callback`: This TensorFlow callback reduces the learning rate when validation accuracy exceeds a set threshold. It's useful for fine-tuning and preventing overfitting by making smaller updates to the model's weights as it learns.

# %%
# Custom callback for reducing learning rate at accuracy values
class ReduceLROnMultipleAccuracies(tf.keras.callbacks.Callback):
    def __init__(self, thresholds, factor, monitor='val_accuracy', verbose=1):
        super(ReduceLROnMultipleAccuracies, self).__init__()
        self.thresholds = thresholds  
        self.factor = factor 
        self.monitor = monitor
        self.verbose = verbose
        self.thresholds_reached = [False] * len(thresholds)  

    def on_epoch_end(self, epoch, logs=None):
        current_accuracy = logs.get(self.monitor)
        for i, threshold in enumerate(self.thresholds):
            if current_accuracy >= threshold and not self.thresholds_reached[i]:
                optimizer = self.model.optimizer
                old_lr = optimizer.learning_rate.numpy()
                new_lr = old_lr * self.factor
                optimizer.learning_rate.assign(new_lr)
                self.thresholds_reached[i] = True  
                if self.verbose > 0:
                    print(f"\nEpoch {epoch+1}: {self.monitor} reached {threshold}. Reducing learning rate from {old_lr} to {new_lr}.")

thresholds = [0.96, 0.99, 0.9935]
lr_callback = ReduceLROnMultipleAccuracies(thresholds=thresholds, factor=0.75, monitor='val_accuracy', verbose=False)

# %%
# history = model.fit(X_train,y_train,epochs=20,validation_split=0.1)

# Callbacks for improved covergence of gradient and best test accuracy
model_rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.8, min_lr=1e-4, patience=4, verbose=False)
model_mc = ModelCheckpoint('model.keras', monitor='val_accuracy', mode='max', save_best_only=True, verbose=False)

# Training the model
history = model.fit(
    train_ds_preprocessed,
    epochs=100,
    validation_data=test_ds_preprocessed,
    callbacks=[model_rlr, model_mc],
    verbose=True
)
# Out:
# Epoch 1/100
#   4/143 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.2559 - loss: 1.3870
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1721734857.115057      77 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 29s 152ms/step - accuracy: 0.4428 - loss: 1.1794 - val_accuracy: 0.5840 - val_loss: 1.0218 - learning_rate: 0.0010
# Epoch 2/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.7586 - loss: 0.6032 - val_accuracy: 0.7710 - val_loss: 0.5829 - learning_rate: 0.0010
# Epoch 3/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 112ms/step - accuracy: 0.8186 - loss: 0.4474 - val_accuracy: 0.7405 - val_loss: 0.6434 - learning_rate: 0.0010
# Epoch 4/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.8743 - loss: 0.3342 - val_accuracy: 0.8359 - val_loss: 0.4809 - learning_rate: 0.0010
# Epoch 5/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 112ms/step - accuracy: 0.9116 - loss: 0.2416 - val_accuracy: 0.8588 - val_loss: 0.3832 - learning_rate: 0.0010
# Epoch 6/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9273 - loss: 0.2011 - val_accuracy: 0.8931 - val_loss: 0.2962 - learning_rate: 0.0010
# Epoch 7/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 17s 114ms/step - accuracy: 0.9464 - loss: 0.1631 - val_accuracy: 0.8779 - val_loss: 0.3717 - learning_rate: 0.0010
# Epoch 8/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9564 - loss: 0.1306 - val_accuracy: 0.9122 - val_loss: 0.2595 - learning_rate: 0.0010
# Epoch 9/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 17s 113ms/step - accuracy: 0.9662 - loss: 0.0926 - val_accuracy: 0.9275 - val_loss: 0.2942 - learning_rate: 0.0010
# Epoch 10/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9575 - loss: 0.1102 - val_accuracy: 0.9351 - val_loss: 0.2331 - learning_rate: 0.0010
# Epoch 11/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 112ms/step - accuracy: 0.9780 - loss: 0.0720 - val_accuracy: 0.9198 - val_loss: 0.2953 - learning_rate: 0.0010
# Epoch 12/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - accuracy: 0.9668 - loss: 0.0917 - val_accuracy: 0.9427 - val_loss: 0.2529 - learning_rate: 0.0010
# Epoch 13/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - accuracy: 0.9791 - loss: 0.0619 - val_accuracy: 0.9466 - val_loss: 0.2770 - learning_rate: 0.0010
# Epoch 14/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9751 - loss: 0.0655 - val_accuracy: 0.9313 - val_loss: 0.2576 - learning_rate: 0.0010
# Epoch 15/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9833 - loss: 0.0410 - val_accuracy: 0.9504 - val_loss: 0.1997 - learning_rate: 8.0000e-04
# Epoch 16/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 21s 113ms/step - accuracy: 0.9855 - loss: 0.0334 - val_accuracy: 0.9656 - val_loss: 0.1649 - learning_rate: 8.0000e-04
# Epoch 17/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9857 - loss: 0.0407 - val_accuracy: 0.9656 - val_loss: 0.1835 - learning_rate: 8.0000e-04
# Epoch 18/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9896 - loss: 0.0326 - val_accuracy: 0.9580 - val_loss: 0.2168 - learning_rate: 8.0000e-04
# Epoch 19/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9870 - loss: 0.0327 - val_accuracy: 0.9237 - val_loss: 0.3331 - learning_rate: 8.0000e-04
# Epoch 20/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9848 - loss: 0.0355 - val_accuracy: 0.9542 - val_loss: 0.2066 - learning_rate: 8.0000e-04
# Epoch 21/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 20s 109ms/step - accuracy: 0.9927 - loss: 0.0218 - val_accuracy: 0.9580 - val_loss: 0.2071 - learning_rate: 6.4000e-04
# Epoch 22/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9944 - loss: 0.0175 - val_accuracy: 0.9618 - val_loss: 0.2204 - learning_rate: 6.4000e-04
# Epoch 23/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9929 - loss: 0.0222 - val_accuracy: 0.9695 - val_loss: 0.2151 - learning_rate: 6.4000e-04
# Epoch 24/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9974 - loss: 0.0087 - val_accuracy: 0.9656 - val_loss: 0.2756 - learning_rate: 6.4000e-04
# Epoch 25/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9965 - loss: 0.0116 - val_accuracy: 0.9580 - val_loss: 0.2453 - learning_rate: 5.1200e-04
# Epoch 26/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 112ms/step - accuracy: 0.9915 - loss: 0.0212 - val_accuracy: 0.9771 - val_loss: 0.2487 - learning_rate: 5.1200e-04
# Epoch 27/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9985 - loss: 0.0055 - val_accuracy: 0.9618 - val_loss: 0.2345 - learning_rate: 5.1200e-04
# Epoch 28/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 17s 114ms/step - accuracy: 0.9962 - loss: 0.0127 - val_accuracy: 0.9618 - val_loss: 0.1971 - learning_rate: 5.1200e-04
# Epoch 29/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9981 - loss: 0.0059 - val_accuracy: 0.9695 - val_loss: 0.2291 - learning_rate: 4.0960e-04
# Epoch 30/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 18s 121ms/step - accuracy: 0.9965 - loss: 0.0116 - val_accuracy: 0.9771 - val_loss: 0.1863 - learning_rate: 4.0960e-04
# Epoch 31/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 17s 113ms/step - accuracy: 0.9981 - loss: 0.0057 - val_accuracy: 0.9733 - val_loss: 0.2398 - learning_rate: 4.0960e-04
# Epoch 32/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 17s 115ms/step - accuracy: 0.9952 - loss: 0.0120 - val_accuracy: 0.9656 - val_loss: 0.3144 - learning_rate: 4.0960e-04
# Epoch 33/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 112ms/step - accuracy: 0.9978 - loss: 0.0048 - val_accuracy: 0.9771 - val_loss: 0.2016 - learning_rate: 3.2768e-04
# Epoch 34/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 17s 115ms/step - accuracy: 0.9989 - loss: 0.0036 - val_accuracy: 0.9733 - val_loss: 0.2044 - learning_rate: 3.2768e-04
# Epoch 35/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 20s 114ms/step - accuracy: 0.9995 - loss: 0.0020 - val_accuracy: 0.9695 - val_loss: 0.2894 - learning_rate: 3.2768e-04
# Epoch 36/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9983 - loss: 0.0044 - val_accuracy: 0.9733 - val_loss: 0.2196 - learning_rate: 3.2768e-04
# Epoch 37/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9990 - loss: 0.0045 - val_accuracy: 0.9771 - val_loss: 0.2131 - learning_rate: 2.6214e-04
# Epoch 38/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9973 - loss: 0.0068 - val_accuracy: 0.9809 - val_loss: 0.2139 - learning_rate: 2.6214e-04
# Epoch 39/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9984 - loss: 0.0040 - val_accuracy: 0.9733 - val_loss: 0.2251 - learning_rate: 2.6214e-04
# Epoch 40/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9992 - loss: 0.0052 - val_accuracy: 0.9809 - val_loss: 0.2461 - learning_rate: 2.6214e-04
# Epoch 41/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9995 - loss: 0.0014 - val_accuracy: 0.9695 - val_loss: 0.2424 - learning_rate: 2.0972e-04
# Epoch 42/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9995 - loss: 9.9085e-04 - val_accuracy: 0.9771 - val_loss: 0.2559 - learning_rate: 2.0972e-04
# Epoch 43/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 112ms/step - accuracy: 0.9993 - loss: 0.0011 - val_accuracy: 0.9695 - val_loss: 0.2680 - learning_rate: 2.0972e-04
# Epoch 44/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 107ms/step - accuracy: 0.9992 - loss: 0.0035 - val_accuracy: 0.9656 - val_loss: 0.3262 - learning_rate: 2.0972e-04
# Epoch 45/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 113ms/step - accuracy: 0.9993 - loss: 0.0027 - val_accuracy: 0.9733 - val_loss: 0.2957 - learning_rate: 1.6777e-04
# Epoch 46/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9995 - loss: 8.8934e-04 - val_accuracy: 0.9733 - val_loss: 0.3334 - learning_rate: 1.6777e-04
# Epoch 47/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - accuracy: 0.9995 - loss: 0.0012 - val_accuracy: 0.9656 - val_loss: 0.3183 - learning_rate: 1.6777e-04
# Epoch 48/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9997 - loss: 6.6724e-04 - val_accuracy: 0.9695 - val_loss: 0.2848 - learning_rate: 1.6777e-04
# Epoch 49/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 17s 113ms/step - accuracy: 0.9994 - loss: 9.6621e-04 - val_accuracy: 0.9618 - val_loss: 0.3454 - learning_rate: 1.3422e-04
# Epoch 50/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9991 - loss: 0.0026 - val_accuracy: 0.9771 - val_loss: 0.3163 - learning_rate: 1.3422e-04
# Epoch 51/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - accuracy: 0.9995 - loss: 9.5586e-04 - val_accuracy: 0.9695 - val_loss: 0.3180 - learning_rate: 1.3422e-04
# Epoch 52/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9996 - loss: 5.0027e-04 - val_accuracy: 0.9771 - val_loss: 0.3136 - learning_rate: 1.3422e-04
# Epoch 53/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9994 - loss: 6.9879e-04 - val_accuracy: 0.9733 - val_loss: 0.3272 - learning_rate: 1.0737e-04
# Epoch 54/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9996 - loss: 5.1678e-04 - val_accuracy: 0.9733 - val_loss: 0.3281 - learning_rate: 1.0737e-04
# Epoch 55/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - accuracy: 0.9995 - loss: 0.0010 - val_accuracy: 0.9771 - val_loss: 0.3250 - learning_rate: 1.0737e-04
# Epoch 56/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9990 - loss: 0.0017 - val_accuracy: 0.9809 - val_loss: 0.3033 - learning_rate: 1.0737e-04
# Epoch 57/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9991 - loss: 0.0014 - val_accuracy: 0.9771 - val_loss: 0.3291 - learning_rate: 1.0000e-04
# Epoch 58/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9997 - loss: 5.4452e-04 - val_accuracy: 0.9771 - val_loss: 0.3148 - learning_rate: 1.0000e-04
# Epoch 59/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 20s 109ms/step - accuracy: 0.9996 - loss: 7.2305e-04 - val_accuracy: 0.9695 - val_loss: 0.3292 - learning_rate: 1.0000e-04
# Epoch 60/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 17s 113ms/step - accuracy: 0.9996 - loss: 6.1794e-04 - val_accuracy: 0.9771 - val_loss: 0.3300 - learning_rate: 1.0000e-04
# Epoch 61/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 107ms/step - accuracy: 0.9997 - loss: 5.8932e-04 - val_accuracy: 0.9771 - val_loss: 0.3132 - learning_rate: 1.0000e-04
# Epoch 62/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - accuracy: 0.9997 - loss: 5.0233e-04 - val_accuracy: 0.9733 - val_loss: 0.3266 - learning_rate: 1.0000e-04
# Epoch 63/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9995 - loss: 6.7499e-04 - val_accuracy: 0.9733 - val_loss: 0.3063 - learning_rate: 1.0000e-04
# Epoch 64/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 112ms/step - accuracy: 0.9994 - loss: 8.2693e-04 - val_accuracy: 0.9809 - val_loss: 0.2699 - learning_rate: 1.0000e-04
# Epoch 65/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9998 - loss: 4.3273e-04 - val_accuracy: 0.9733 - val_loss: 0.2760 - learning_rate: 1.0000e-04
# Epoch 66/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9996 - loss: 5.7285e-04 - val_accuracy: 0.9771 - val_loss: 0.2833 - learning_rate: 1.0000e-04
# Epoch 67/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9997 - loss: 5.4035e-04 - val_accuracy: 0.9771 - val_loss: 0.2808 - learning_rate: 1.0000e-04
# Epoch 68/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9996 - loss: 4.8114e-04 - val_accuracy: 0.9733 - val_loss: 0.3065 - learning_rate: 1.0000e-04
# Epoch 69/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - accuracy: 0.9995 - loss: 6.4464e-04 - val_accuracy: 0.9733 - val_loss: 0.3180 - learning_rate: 1.0000e-04
# Epoch 70/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9997 - loss: 4.8354e-04 - val_accuracy: 0.9733 - val_loss: 0.3250 - learning_rate: 1.0000e-04
# Epoch 71/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9994 - loss: 5.8437e-04 - val_accuracy: 0.9771 - val_loss: 0.3180 - learning_rate: 1.0000e-04
# Epoch 72/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9998 - loss: 4.1369e-04 - val_accuracy: 0.9771 - val_loss: 0.3164 - learning_rate: 1.0000e-04
# Epoch 73/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - accuracy: 0.9997 - loss: 6.8409e-04 - val_accuracy: 0.9771 - val_loss: 0.2558 - learning_rate: 1.0000e-04
# Epoch 74/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9995 - loss: 8.0601e-04 - val_accuracy: 0.9733 - val_loss: 0.3028 - learning_rate: 1.0000e-04
# Epoch 75/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - accuracy: 0.9996 - loss: 4.6860e-04 - val_accuracy: 0.9733 - val_loss: 0.3164 - learning_rate: 1.0000e-04
# Epoch 76/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9997 - loss: 7.3807e-04 - val_accuracy: 0.9809 - val_loss: 0.3269 - learning_rate: 1.0000e-04
# Epoch 77/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 21s 113ms/step - accuracy: 0.9998 - loss: 5.3751e-04 - val_accuracy: 0.9847 - val_loss: 0.3294 - learning_rate: 1.0000e-04
# Epoch 78/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9996 - loss: 5.9989e-04 - val_accuracy: 0.9733 - val_loss: 0.3142 - learning_rate: 1.0000e-04
# Epoch 79/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 17s 113ms/step - accuracy: 0.9994 - loss: 5.9460e-04 - val_accuracy: 0.9733 - val_loss: 0.2457 - learning_rate: 1.0000e-04
# Epoch 80/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9996 - loss: 6.5506e-04 - val_accuracy: 0.9809 - val_loss: 0.2869 - learning_rate: 1.0000e-04
# Epoch 81/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - accuracy: 0.9996 - loss: 4.9080e-04 - val_accuracy: 0.9771 - val_loss: 0.2608 - learning_rate: 1.0000e-04
# Epoch 82/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9997 - loss: 5.1028e-04 - val_accuracy: 0.9771 - val_loss: 0.2761 - learning_rate: 1.0000e-04
# Epoch 83/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9995 - loss: 5.8583e-04 - val_accuracy: 0.9771 - val_loss: 0.2270 - learning_rate: 1.0000e-04
# Epoch 84/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 112ms/step - accuracy: 0.9994 - loss: 6.6638e-04 - val_accuracy: 0.9733 - val_loss: 0.2690 - learning_rate: 1.0000e-04
# Epoch 85/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9998 - loss: 4.7831e-04 - val_accuracy: 0.9771 - val_loss: 0.2881 - learning_rate: 1.0000e-04
# Epoch 86/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 17s 113ms/step - accuracy: 0.9995 - loss: 6.7121e-04 - val_accuracy: 0.9771 - val_loss: 0.2745 - learning_rate: 1.0000e-04
# Epoch 87/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9995 - loss: 6.3314e-04 - val_accuracy: 0.9733 - val_loss: 0.3174 - learning_rate: 1.0000e-04
# Epoch 88/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 112ms/step - accuracy: 0.9996 - loss: 7.1369e-04 - val_accuracy: 0.9809 - val_loss: 0.2538 - learning_rate: 1.0000e-04
# Epoch 89/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - accuracy: 0.9997 - loss: 6.0272e-04 - val_accuracy: 0.9809 - val_loss: 0.2749 - learning_rate: 1.0000e-04
# Epoch 90/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9997 - loss: 6.7204e-04 - val_accuracy: 0.9771 - val_loss: 0.3245 - learning_rate: 1.0000e-04
# Epoch 91/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 20s 109ms/step - accuracy: 0.9998 - loss: 4.7479e-04 - val_accuracy: 0.9771 - val_loss: 0.3191 - learning_rate: 1.0000e-04
# Epoch 92/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 17s 113ms/step - accuracy: 0.9995 - loss: 5.6686e-04 - val_accuracy: 0.9771 - val_loss: 0.3054 - learning_rate: 1.0000e-04
# Epoch 93/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9996 - loss: 5.1828e-04 - val_accuracy: 0.9809 - val_loss: 0.3041 - learning_rate: 1.0000e-04
# Epoch 94/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 17s 114ms/step - accuracy: 0.9996 - loss: 5.2935e-04 - val_accuracy: 0.9809 - val_loss: 0.3043 - learning_rate: 1.0000e-04
# Epoch 95/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9997 - loss: 5.3692e-04 - val_accuracy: 0.9733 - val_loss: 0.2887 - learning_rate: 1.0000e-04
# Epoch 96/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9997 - loss: 4.4704e-04 - val_accuracy: 0.9771 - val_loss: 0.2975 - learning_rate: 1.0000e-04
# Epoch 97/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - accuracy: 0.9995 - loss: 6.1420e-04 - val_accuracy: 0.9771 - val_loss: 0.2769 - learning_rate: 1.0000e-04
# Epoch 98/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 111ms/step - accuracy: 0.9996 - loss: 5.9212e-04 - val_accuracy: 0.9809 - val_loss: 0.2960 - learning_rate: 1.0000e-04
# Epoch 99/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 21s 115ms/step - accuracy: 0.9997 - loss: 5.9744e-04 - val_accuracy: 0.9733 - val_loss: 0.3665 - learning_rate: 1.0000e-04
# Epoch 100/100
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9995 - loss: 7.4857e-04 - val_accuracy: 0.9771 - val_loss: 0.3377 - learning_rate: 1.0000e-04

# %%
# Loading saved model
model = load_model('model.keras')

# Evaluate model and test data accuracy
test_loss, test_acc = model.evaluate(test_ds_preprocessed)
print(f"Test accuracy: {test_acc*100:0.4f}%")
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9901 - loss: 0.2036
# Test accuracy: 98.4733%

# %%
# Save the history
with open('training_history.pkl', 'wb') as file:
    pickle.dump(history.history, file)
    
    
# Load the training history
with open('training_history.pkl', 'rb') as file:
    history = pickle.load(file)

# Extract the data
acc = history['accuracy']
val_acc = history['val_accuracy']
loss = history['loss']
val_loss = history['val_loss']
epochs = range(len(acc))

# Plot accuracy
fig = plt.figure(figsize=(13,7))
plt.title("training vs testing acuuracy")
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.legend(loc='upper left')
plt.show()

# Plot loss
fig = plt.figure(figsize=(13,7))
plt.title("training vs testing loss")
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.legend(loc='upper left')
plt.show()

# %%
img = cv2.imread('/kaggle/input/brain-tumor-mri-dataset/Testing/pituitary/Te-piTr_0000.jpg')
img = cv2.resize(img,(168,168))
img_array = np.array(img)
img_array = img_array.reshape(1,168,168,3)
img_array.shape
# Out:
# (1, 168, 168, 3)

# %%
img = image.load_img('/kaggle/input/brain-tumor-mri-dataset/Testing/pituitary/Te-piTr_0000.jpg')
plt.imshow(img,interpolation='nearest')
plt.show()

# %%
a = model.predict(img_array)
indeces = a.argmax()
print(indeces)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 673ms/step
# 2

# %% [markdown]
# <img style="width: 60%; height: auto; padding: 20px  auto; margin: 20px auto; display: block ; display: block; border-radius: 50px 50px;" src="https://media.giphy.com/media/v1.Y2lkPTc5MGI3NjExaWFsMmxudnF2dm84aGs5NW9lcW9zaXdvM3N6eW55YzY4cjc5bm94MiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/smaaKxR6ZrQYQxHFfA/giphy.gif">

# %% [markdown]
#  <div align="center">
#   <a href="mailto:hassaneskikri@gmail.com">
#     <img src="https://img.shields.io/badge/Gmail-333333?style=for-the-badge&logo=gmail&logoColor=red" />
#   </a>
#   <a href="https://www.linkedin.com/in/hassane-skikri-3224bb255/" target="_blank">
#     <img src="https://img.shields.io/badge/LinkedIn-0077B5?style=for-the-badge&logo=linkedin&logoColor=white" target="_blank" />
#   </a>
#   <a href="https://hassaneskikri.github.io/skikriPortfolio/" target="_blank">
#      <img src="https://img.shields.io/badge/Portfolio-FF5722?style=for-the-badge&logo=todoist&logoColor=white" target="_blank" />
#   </a>
#    <a href="https://medium.com/@Hassane_01" target="_blank">
#     <img src="https://img.shields.io/badge/Medium-12100E?style=for-the-badge&logo=medium&logoColor=white" target="_blank" />
#   </a>
#     <a href="https://www.kaggle.com/hassaneskikri" target="_blank">
#     <img src="https://img.shields.io/badge/Kaggle-20BEFF?style=for-the-badge&logo=Kaggle&logoColor=white" target="_blank" />
#   </a>
#     <a href="https://github.com/HassaneSkikri" target="_blank">
#     <img src="https://img.shields.io/badge/GitHub-100000?style=for-the-badge&logo=github&logoColor=white" target="_blank" />
#   </a>
